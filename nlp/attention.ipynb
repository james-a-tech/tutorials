# %% [markdown]
# # Demenstartion of Basic attention model
# ![image.png](attachment:image.png)
#
# Equation :
# $$
# \large e_{ij} = v_a^\top \tanh{\left(W_a s_{i-1} + U_a h_j\right)}
# $$
#
# Here $h_j$ are the encoder hidden states for each input step $j$ and $s_{i - 1}$ is the decoder hidden state of the previous step.

# %% [markdown]
# References for this lab
# https://github.com/johnmoses/coursera-nlp-specialization/blob/main/C4-natural-language-processing-with-attention-models/Week1/C4_W1_Ungraded_Lab_1_Basic_Attention.ipynb
