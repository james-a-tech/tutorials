# %%
import matplotlib.pyplot as plt

sales = [112, 118, 132, 129, 121, 135, 148, 151, 148, 136, 119, 104]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

plt.plot(months, sales)
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
import pandas as pd

sales_series = pd.Series(sales)
sales_diff = sales_series.diff().dropna()
sales_diff
# plt.plot(sales_diff)
# plt.title('First Order Differenced Sales Data')
# plt.xlabel('Month')
# plt.ylabel('Differenced Sales')
# plt.show()
# Out:
# 1      6.0
# 2     14.0
# 3     -3.0
# 4     -8.0
# 5     14.0
# 6     13.0
# 7      3.0
# 8     -3.0
# 9    -12.0
# 10   -17.0
# 11   -15.0
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(sales_diff)
plt.show()

plot_pacf(sales_diff)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#       3 plot_acf(sales_diff)
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'statsmodels'
